# %% [markdown]
# *Write a python program that takes in a student name, class, and section. It should also take in five subject marks of the students and find the total mark and percentage. Display a result in such a way that their name, class, section, and percentage are printed.
# *Input 3 numbers and return sum of them.
# *Input a number and return square of it.
# *Write a program to:
# Take the temperature in Celsius as input (string format).
# Convert it into a float.
# Calculate the equivalent temperature in Fahrenheit using the formula: Fahrenheit=(Celsius×9/5​)+32
# Print the result in both Celsius and Fahrenheit.
# *Write a program to calculate the remainder when a number is divided by another number.
# Input: Two integers from the user.
# Output: Quotient and remainder.
# *Write a program to calculate using the formula:
#
#
# SI = (P × R × T) / 100
#
# where P = Principal, R = Rate, T = Time.

# %%
student_name=(input("enter student_name"))
class_=(input("enter class"))
section=(input("enter section"))
subject1=int(input("enter marks")) 
subject2=int(input("enter marks"))
subject3=int(input("enter marks"))
subject4=int(input("enter marks"))
subject5=int(input("enter marks"))
sum=(subject1+subject2+subject3+subject4+subject5)
percentage=int((subject1+subject2+subject3+subject4+subject5)/500)
percentage2=int((percentage)/2)
print("name of student ", student_name)
print("class name ", class_)
print("section name ", section)
print("percentage is ", percentage)
# Out:
# name of student  df
# class name  3
# section name  f
# percentage is  0

# %%
a=10
b=15
c=20
s=a+b+c
print(s)
# Out:
# 45

# %%
a=5
s=a**2
print(s)
# Out:
# 25

# %%
temp=(input("temp.celsius"))
print(str(temp))
print(float(temp))
# Out:
# 65
# 65.0

# %%
num1=int(input("enter a number: "))
num2=int(input("enter a number: "))

print("division:", num1 / num2)
print("modulus:", num1 % num2)
# Out:
# division: 0.8735632183908046
# modulus: 76

# %%
p=800
s=76
t=95
print((p*s*t)/100)
# Out:
# 57760.0
