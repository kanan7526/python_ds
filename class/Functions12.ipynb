# %% [markdown]
# ## Functions
# - ### Definition
#
# - A Function is a block of code that performs a specific task.Functions helps in organizing code,reusing code and improcing readability

# %%
## Syntax
def function_name(parameters):
    """Docstring"""      #(Optional) Used to describe what the function does.
    #Function body
    return expression  #(Optional) Used to return a value from the function. If not specified, the function will return None by default.

# %%
## Why Functions?
num=24
if num%2==0:
    print("The Number is Even.")
else:
    print("The Number is Odd")

# %%
def even_or_odd(num):
    """This functions finds even or odd numbers"""     #not compulsary to write #information of func
    if num%2==0:
        print("The Number is Even.")
    else:
        print("The Number is Odd")

# %%
# Now we will call the function
even_or_odd(22)

# %%
even_or_odd(23)

# %%
def sumss():
    print("hello")
    return 'Hello'


print(sumss())
sumss()

# %%
# Function with Mutiple parameters
# Parameters can be anything as str,int etc

def add(a,b):
    c = a+b 
    return  c

print(add(2,6))
 
# return functions send the value back
# as we don write return it says none that is no value is returned

# %%
# return ends the function immediately
# It sends a value back to the caller
# You can store that value in a variable or print it

# %%
def sumss(a,b):     #Parameters
    return a+b
    
i=int(input("Enter i "))
j=int(input("Enter j "))
ans=sumss(i,j)  # Arguments
print(ans)

# %% [markdown]
# ### Functions with Default parameters

# %%
def greet(name):
    print(f"Hello! {name}, How are you?")

greet("Sourav")
greet("kanan")

# %%
def greet(name):
    print(f"Hello! {name}, How are you?")

greet()

# %%
def greet(name="Guest"):
    print(f"Hello! {name}, How are you?")

# greet()
greet("Kanan")

# %%
def printnumber(a,b,c):
    print(a,b,c)
    
# i=10
# j=20
# k=30
# printnumber(i,j,k)
# printnumber(i=10,j=20,k=30) # error
# printnumber(10,20,30)
printnumber(c=10,b=20,a=30)   #Positinal Arguments

# %%
def student(fname, sname):
    print(fname, sname)

student(fname='Sourav', sname='Kanan')
student(sname='Kanan', fname='Sourav')  #Keyword Arguments

# %%
def printnumber(num1,num2,num3,num4):
    print(num1,num2,num3,num4)

printnumber(1,2,3)

# %%
# Variable length arguments
# Positinal Arguments and Keyword Arguments

#  Arbitrary Arguments:
# (Non-Keyword Arguments(*agrs) and Keyword Arguments(**kwargs)


def print_numbers(*args):     #used to take many inputs  #Positional Arguments
    for item in args:
        print(item)


print_numbers("sourav")

# %%
## Keyword Arguments(**kwargs)
#In keyword arguments we can pass the value with the name of the parameter i.e in key value pair form

def print_details(**kwargs):
    for key,value in kwargs.items():
        print(f"{key} : {value}")

# print_details(Name="Sourav",Age=22,Country="India")
print_details("name":"sourav","age":22,"country":"India") #error

# %%
def print_details(*args,**kwargs):    
        for val in args:
            print(f"Positinal Arguments :{val}")

        for key,value in kwargs.items():
            print(f"{key} : {value}")

# %%
print_details(1,2,3,4,5,6,Name="Sourav",Age=22,Country="India")

# %%
# Return statements
def multiply(a,b):
    return a*b

multiply(2,3)

# %%
def multiply(a,b):
    return a*b,a+b,a,b  #return statement can return multiple values/parameters as tuple

multiply(2,3)

# %%
# Local Variables:
# A local variable is created inside a function and can only be used within that function.

def my_function():
    x = 10   # local variable
    print(x)

my_function()
# print(x)  ❌ Error (outside the function)
print(x)
#x exists only inside my_function().
# Out:
# 10
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 10
#       8 my_function()
#       9 # print(x)  ❌ Error (outside the function)
# ---> 10 print(x)
#      11 #x exists only inside my_function().
#
# NameError: name 'x' is not defined

# %%
# Global Variables:
# A global variable is defined outside all functions and can be accessed anywhere in the program.

x = 20   # global variable

def my_function():
    print(x)

my_function()
print(x)

# Same x is used both inside and outside the function.
# Out:
# 20
# 20
