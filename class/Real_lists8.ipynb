# %% [markdown]
# ## Real worls examples using lists
#
# - Lists are the one one of the most commonly used data structure because of its ease of use and versatile nature

# %% [markdown]
# ## Example:1 Manage a todo list

# %% [markdown]
# - Create a to-do list of daily tasks

# %%
to_do_list=["Go college","Complete Assignments","Play game"]

#Adding a new task

to_do_list.append("Go for grocery")
to_do_list.append("Make dinner")



# removing a done task
to_do_list.remove("Complete Assignments")

print("-----------------")

#checking if a task in to_do list
if "Go college" in to_do_list:
    print("Compulsary for Attendance")

print("-----------------")

print("to_do_list remaining")
for task in to_do_list:
    print(task)
# Out:
# -----------------
# Compulsary for Attendance
# -----------------
# to_do_list remaining
# Go college
# Play game
# Go for grocery
# Make dinner

# %% [markdown]
# ## Example:2 Organinzing students grades

# %%
# List of student grades
grades = [85, 92, 78, 90, 88]

# Adding a new grade
grades.append(95)

# Calculating the average grade
average_grade = sum(grades) / len(grades)
print(f"Average Grade: {average_grade:.3f}")

# Finding the highest and lowest grades
highest_grade = max(grades)
lowest_grade = min(grades)

print(f"Highest Grade: {highest_grade}")
print(f"Lowest Grade: {lowest_grade}")
# Out:
# Average Grade: 88.000
# Highest Grade: 95
# Lowest Grade: 78

# %%
# what is 2f
# If average_grade = 88.8333333
# Without formatting:
# 88.8333333
# With :.2f:
# 88.83

# %%
#common more formatting instructions
# ==============================
# PYTHON F-STRING FORMATTING
# ==============================

# x = 123.4567
# text = "Hi"
# num = 42
# n = 1000000
# p = 0.875

# # 1. Decimal / Float Formatting
# print(f"{x:.2f}")    # 123.46
# print(f"{x:.0f}")    # 123
# print(f"{x:10.2f}")  # width 10, right aligned

# # 2. Width & Alignment
# print(f"{text:>10}")  # right aligned
# print(f"{text:<10}")  # left aligned
# print(f"{text:^10}")  # centered

# # 3. Sign Control
# print(f"{num:+}")   # +42
# print(f"{num:-}")   # 42
# print(f"{num: }")   # space for positive

# # 4. Thousands Separator
# print(f"{n:,}")     # 1,000,000

# # 5. Percentage
# print(f"{p:.2%}")   # 87.50%

# # 6. String Truncation
# print(f"{text:.1}") # H

# # 7. Integer Bases
# print(f"{num:b}")   # binary
# print(f"{num:o}")   # octal
# print(f"{num:x}")   # hex (lowercase)
# print(f"{num:X}")   # hex (uppercase)

# # 8. Scientific Notation
# print(f"{x:.2e}")   # 1.23e+02

# # 9. Zero Padding
# print(f"{num:03}")  # 042
# print(f"{num:08}")  # 00000042

# # 10. Combined Formatting
# print(f"{x:,.2f}")      # 123.46 (with commas if large)
# print(f"{x:>12,.2f}")   # aligned + commas

# %% [markdown]
# ## Managing inventory

# %%
# Managing an inventory
inventory = ["apples", "bananas", "oranges", "grapes"]

# Adding a new item
inventory.append("strawberries")

# Removing an item that is out of stock
inventory.remove("bananas")

# Checking if an item is in stock
item = "oranges"
if item in inventory:
    print(f"{item} are in stock.")
else:
    print(f"{item} are out of stock.")

# Printing the inventory
print("Inventory List:")
for item in inventory:
    print(f"-{item}")
# Out:
# oranges are in stock.
# Inventory List:
# -apples
# -oranges
# -grapes
# -strawberries

# %% [markdown]
# ## Collecting user Feedback

# %%
# Collecting user feedback
feedback = ["Great service!", "Very satisfied", "Could be better", "Excellent experience"]

# Adding new feedback
feedback.append("Not happy with the service")

# Counting specific feedback
positive_feedback_count = sum(
    1 for comment in feedback
    if "great" in comment.lower() or "excellent" in comment.lower() or "satisfied" in comment.lower()
)
print(f"Positive Feedback Count: {positive_feedback_count}")

# Printing all feedback
print("User Feedback:")
for comment in feedback:
    print(f"- {comment}")
# Out:
# Positive Feedback Count: 3
# User Feedback:
# - Great service!
# - Very satisfied
# - Could be better
# - Excellent experience
# - Not happy with the service
