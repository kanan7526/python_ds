# %% [markdown]
# Q1 Take a empty Dictionary and Ask user to input the number of time they want to enter and input form user to make dict
#
# Q2Given a dictionary employee_details where the keys are employee IDs and values are dictionaries with name, department, and salary, filter and create a list of names of employees who have a salary greater than 50,000.
#
# <!-- Q3 Write a program for a number guessing game where the computer randomly selects a number between 1 and 100, and the user tries to guess it. The program should give hints if the guess is too high or too low. -->
#
#
# Q4 Write a program to count how many times each character appears in a string using a dictionary.
# 👉 Input: "hello"
# 👉 Output: {'h':1, 'e':1, 'l':2, 'o':1}
#
#
# 5. Create Dictionary from Two Lists
# Given two lists:
#
# keys = ['a','b','c']
# values = [10,20,30]
#
# 6 Create a dictionary.
#
# Store 5 students’ marks in a dictionary and:
# Find highest marks
# Find lowest marks

# %%
dict={}
n=int(input("enter number of elements in dict"))
 
for i in range(n):
    keys=input("enter keys")
    values=input("enter values")
    dict[keys] = values
print(dict)

# %%
employees_details={11:{"name":"Rohan","Department":"cse","salary":58000},
                   12:{"name":"Rohit","Department":"ece","salary":45000},
                   13:{"name":"Mohit","Department":"it","salary":62000},
                   14:{"name":"Priya","Department":"hr","salary":25000},
                   15:{"name":"Mahi","Department":"btech","salary":38000}}
for emp_id, details in employees_details.items():
    if(details["salary"] > 50000):
        print("salary:", details["salary"])
# Out:
# salary: 58000
# salary: 62000

# %%
dict=input("enter the string: ")
char_count={}
char_count = {ch: dict.count(ch) for ch in dict}
print(char_count)
# Out:
# {'k': 1, 'a': 2, 'n': 2}

# %%
keys = ['a','b','c']
values = [10,20,30]
dict1=dict(zip(keys,values))
print(dict1)
# Out:
# {'a': 10, 'b': 20, 'c': 30}

# %%
keys=['a','b','c','d','e']
values=[50,60,83,24,90]
dict1=dict(zip(keys,values))
print(dict1)
highest=max(dict1.values())
print("highest marks are",highest)
lowest=min(dict1.values())
print("lowest marks are",lowest)
# Out:
# {'a': 50, 'b': 60, 'c': 83, 'd': 24, 'e': 90}
# highest marks are 90
# lowest marks are 24
