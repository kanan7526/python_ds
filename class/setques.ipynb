# %% [markdown]
# 1Q You are given two sets of guest names:
#
# friday = {"Alice", "Bob", "Charlie"}
# saturday = {"Charlie", "David", "Eve"}
# Tasks:
# Create a new set called all_guests that contains everyone attending at least one night.
# Identify the guest(s) who are attending .
#
# 2Q You are given a list with duplicate values:
#
# data = [1, 2, 2, 3, 4, 4, 4, 5]
# Tasks:
# Convert this list into a  to remove duplicates.
# Add the number 6 to the resulting set.
#
# 3Q You are given:
#
# library_books = {"Hobbit", "1984", "Gatsby", "Odyssey", "Hamlet"}
# checked_out = {"1984", "Hamlet"}
# Tasks:
# Find the books currently .
# A student donates "Don Quixote":
# Check if it is  in library_books before adding it.
#
# 4Q You are given:
#
# user_permissions = {"read", "write"}
# admin_reqs = {"read", "write", "execute"}
# Tasks:
# • Task: Use a method to check if the user has all the permissions required for admin access (Is
# the user's set a subset of the requirements?).
# • Task: Find the specific permissions the user is missing
#
# 5Q You are given a dictionary:
#
# logs = {
# "404": [10, 12, 15, 20],
# "500": [12, 20, 22, 25],
# "403": [10, 20, 30]
# }
# Tasks:
# • Task: Use a Set Comprehension to create a new set containing only the Server IDs that
# experienced every type of error (404, 500, AND 403).
# • Task: Identify the "Critical Servers"—these are servers that experienced a "500" error but
# never experienced a "404" error

# %%
friday = {"Alice", "Bob", "Charlie"}
saturday = {"Charlie", "David", "Eve"}
attended_one_night = friday.intersection(saturday)
print(attended_one_night)
attended_both_nights=friday.union(saturday)
print(attended_both_nights)

# %%
data = [1, 2, 2, 3, 4, 4, 4, 5]
unique_data=set(data)
print(unique_data)
unique_data.add(6)
print(unique_data)

# %%
library_books = {"Hobbit", "1984", "Gatsby", "Odyssey", "Hamlet"}
checked_out = {"1984", "Hamlet"}
available_books=library_books.difference(checked_out)
print(available_books)

# %%
user_permissions = {"read", "write"}
admin_reqs = {"read", "write", "execute"}
is_subset= user_permissions.issubset(admin_reqs)
print("is_subset",is_subset)
missing_permissions=admin_reqs.difference(user_permissions)
print(missing_permissions)
# Out:
# is_subset True
# {'execute'}

# %%
logs = {
"404": [10, 12, 15, 20],
"500": [12, 20, 22, 25],
"403": [10, 20, 30]
}
server_ids={server for server in logs["404"] if server in logs["500"] and server in logs["403"]}
print(server_ids)
server_ids1={server for server in logs["500"] if server not in logs["404"]}
print(server_ids1)
# Out:
# {20}
# {25, 22}
